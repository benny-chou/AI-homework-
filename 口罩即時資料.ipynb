# %%
import csv 
import requests
import pandas as pd

prefix="新竹市"
url="http://data.nhi.gov.tw/Datasets/Download.ashx?rid=A21030000I-D50001-001&l=https://data.nhi.gov.tw/resource/mask/maskdata.csv"

download = requests.get(url)
decoded_content = download.content.decode("utf-8")
cr = csv.reader(decoded_content.splitlines(), delimiter=",")

original_list = list(cr)
#print(original_list)

mask_df = pd.DataFrame(original_list)
mask_df.head()
# Out:
#             0                 1                  2             3        4  \
# 0     ﻿醫事機構代碼            醫事機構名稱             醫事機構地址        醫事機構電話  成人口罩剩餘數
# 1  0145080011  衛生福利部花蓮醫院豐濱原住民分院    花蓮縣豐濱鄉豐濱村光豐路４１號       8358141     1580
# 2  0291010010            連江縣立醫院      連江縣南竿鄉復興村２１７號        623995     1719
# 3  2101010013          松山健康服務中心  臺北市松山區八德路４段６９２號６樓  (02)27671757     2180
# 4  2101020019          大安健康服務中心     臺北市大安區辛亥路３段１５號  (02)27335831      596
#
#          5                    6
# 0  兒童口罩剩餘數               來源資料時間
# 1     1084  2020/10/28 15:08:41
# 2      590  2020/10/28 15:08:41
# 3      110  2020/10/28 15:08:41
# 4      816  2020/10/28 15:08:41
